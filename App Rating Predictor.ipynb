# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
from collections import Counter

# %%
data2=pd.read_csv('Google-Playstore-Full.csv',encoding='Latin-1',low_memory=False,error_bad_lines=False)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267052 entries, 0 to 267051
# Data columns (total 15 columns):
# App Name           267051 non-null object
# Category           267051 non-null object
# Rating             267052 non-null object
# Reviews            267051 non-null object
# Installs           267052 non-null object
# Size               267052 non-null object
# Price              267052 non-null object
# Content Rating     267052 non-null object
# Last Updated       267052 non-null object
# Minimum Version    267051 non-null object
# Latest Version     267049 non-null object
# Unnamed: 11        18 non-null object
# Unnamed: 12        3 non-null object
# Unnamed: 13        2 non-null object
# Unnamed: 14        1 non-null float64
# dtypes: float64(1), object(14)
# memory usage: 30.6+ MB

# %%
data2.head()
# Out:
#                                             App Name          Category  \
# 0                           DoorDash - Food Delivery    FOOD_AND_DRINK
# 1  TripAdvisor Hotels Flights Restaurants Attract...  TRAVEL_AND_LOCAL
# 2                                             Peapod          SHOPPING
# 3                    foodpanda - Local Food Delivery    FOOD_AND_DRINK
# 4                          My CookBook Pro (Ad Free)    FOOD_AND_DRINK
#
#         Rating  Reviews      Installs                Size  Price  \
# 0  4.548561573   305034    5,000,000+  Varies with device      0
# 1  4.400671482  1207922  100,000,000+  Varies with device      0
# 2  3.656329393     1967      100,000+                1.4M      0
# 3  4.107232571   389154   10,000,000+                 16M      0
# 4  4.647752285     2291       10,000+  Varies with device  $5.99
#
#   Content Rating        Last Updated     Minimum Version      Latest Version  \
# 0       Everyone      March 29, 2019  Varies with device  Varies with device
# 1       Everyone      March 29, 2019  Varies with device  Varies with device
# 2       Everyone  September 20, 2018          5.0 and up               2.2.0
# 3       Everyone      March 22, 2019          4.2 and up              4.18.2
# 4       Everyone       April 1, 2019  Varies with device  Varies with device
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN

# %%
data2.columns
# Out:
# Index(['App Name', 'Category', 'Rating', 'Reviews', 'Installs', 'Size',
#        'Price', 'Content Rating', 'Last Updated', 'Minimum Version',
#        'Latest Version', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
data2.rename(columns={'App Name':'app_name','Category':'category','Rating':'rating','Reviews':'reviews','Installs':'installs',
                    'Size':'size','Price':'price','Content Rating':'content_rating','Last Updated':'last_updated',
                    'Minimum Version':'minimum_version','Latest Version':'latest_version','Unnamed: 11':'unnamed1',
                    'Unnamed: 12':'unnamed2','Unnamed: 13':'unnamed3','Unnamed: 14':'unnamed4'},inplace=True)

# %%
data2.columns
# Out:
# Index(['app_name', 'category', 'rating', 'reviews', 'installs', 'size',
#        'price', 'content_rating', 'last_updated', 'minimum_version',
#        'latest_version', 'unnamed1', 'unnamed2', 'unnamed3', 'unnamed4'],
#       dtype='object')

# %%
data2['unnamed4'].value_counts()
# Out:
# 9.1    1
# Name: unnamed4, dtype: int64

# %%
data2[data2["rating"]==' Economics']
# Out:
#                         app_name     category      rating  \
# 232811  Learn Accounts - Finance   Accounting   Economics
#
#                     reviews     installs size   price content_rating  \
# 232811  BOOKS_AND_REFERENCE  4.823529243   17  1,000+            17M
#
#        last_updated minimum_version    latest_version      unnamed1 unnamed2  \
# 232811            0        Everyone  October 22, 2018  4.0.3 and up        1
#
#        unnamed3  unnamed4
# 232811      NaN       NaN

# %%
data2.drop([6941,13504,23457,48438,32229,113151,125479,125480,180371,165230,168914,177165,193869,257773,190759
           ,194165,232811],inplace=True)

# %%
data2["rating"]=data2["rating"].astype({"rating":float})

# %%
data2[data2['rating']>5.0]
# Out:
#             app_name category  rating reviews installs             size  \
# 99584  ???? ????? 5         6     7.0       8   Xmax X  MUSIC_AND_AUDIO
#
#              price content_rating last_updated minimum_version latest_version  \
# 99584  4.468125343           3702     500,000+             21M              0
#
#        unnamed1           unnamed2    unnamed3  unnamed4
# 99584  Everyone  February 14, 2019  4.4 and up       9.1

# %%
data2.drop(99584,inplace=True)

# %%
data2[data2.index==[267033]]
# Out:
#                                  app_name   category    rating reviews  \
# 267033  Bangla Alphabets (????? ????????)  EDUCATION  3.545455      11
#
#        installs size price content_rating     last_updated minimum_version  \
# 267033   1,000+  21M     0       Everyone  October 5, 2018      4.1 and up
#
#        latest_version unnamed1 unnamed2 unnamed3  unnamed4
# 267033        1.0.0.3      NaN      NaN      NaN       NaN

# %%
data2["reviews"]=data2["reviews"].astype({"reviews":float})

# %%
data2["installs"] = [x.replace(',','') for x in data2["installs"]]

# %%
data2["installs"] = [x.strip('+') for x in data2["installs"]]

# %%
data2["installs"]=data2["installs"].astype({"installs":float})

# %%
data2["size"] = [x.replace('Varies with device','NaN') for x in data2["size"]]

# %%
data2["size"] = [x.replace('M','000000') for x in data2["size"]]

# %%
data2["size"] = [x.replace('k','000') for x in data2["size"]]

# %%
data2["size"] = [x.replace(',','') for x in data2["size"]]

# %%
data2["size"]=data2["size"].astype({"size":float})

# %%
data2["price"] = [x.strip('$') for x in data2["price"]]

# %%
data2["price"]=data2["price"].astype({"price":float})

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267034 entries, 0 to 267051
# Data columns (total 15 columns):
# app_name           267033 non-null object
# category           267034 non-null object
# rating             267034 non-null float64
# reviews            267034 non-null float64
# installs           267034 non-null float64
# size               255308 non-null float64
# price              267034 non-null float64
# content_rating     267034 non-null object
# last_updated       267034 non-null object
# minimum_version    267033 non-null object
# latest_version     267031 non-null object
# unnamed1           0 non-null object
# unnamed2           0 non-null object
# unnamed3           0 non-null object
# unnamed4           0 non-null float64
# dtypes: float64(6), object(9)
# memory usage: 32.6+ MB

# %%
def cost(price):
    if price>0.0:
        return 1
    else:
        return 0

# %%
data2["price"]=data2["price"].apply(cost)

# %%
data2['price'].value_counts()
# Out:
# 0    255428
# 1     11606
# Name: price, dtype: int64

# %%
data2['last_updated']=pd.to_datetime(data2['last_updated'].astype(str), format='%B %d, %Y')

# %%
data2['last_updated']=data2['last_updated'].astype({'last_updated':str})

# %%
data2[data2['last_updated']=='19']
# Out:
# Empty DataFrame
# Columns: [app_name, category, rating, reviews, installs, size, price, content_rating, last_updated, minimum_version, latest_version, unnamed1, unnamed2, unnamed3, unnamed4]
# Index: []

# %%
data2['latest_version'].value_counts()
# Out:
# 1                     33002
# 1.1                   11714
# Varies with device     8553
# 1.2                    8205
# 2                      7126
# 1.3                    5922
# 1.4                    4400
# 1.0.0                  4146
# 1.0.1                  4073
# 3                      3815
# 1.5                    3671
# 1.0.2                  3118
# 1.6                    2670
# 2.1                    2517
# 1.0.3                  2365
# 4                      2114
# 1.7                    1977
# 1.0.4                  1862
# 1.1.0                  1757
# 1.0.5                  1682
# 1.1.1                  1652
# 2.2                    1640
# 1.8                    1635
# 1.0.6                  1416
# 5                      1403
# 1.9                    1390
# 2.3                    1280
# 2.0.0                  1237
# 1.0.7                  1127
# 1.1.2                  1113
#                       ...
# Speakers 79               1
# 16.0.de6ae53              1
# 2.3.3935                  1
# 0.30.3                    1
# 10.0.424                  1
# 2.3.89607                 1
# 1.00012                   1
# 1.8.116                   1
# 4.76.04                   1
# 7.0.12-qa015-prod         1
# 2.0.300                   1
# 1.0.1 (3)                 1
# 1.0032                    1
# 12.28                     1
# 1.09.3                    1
# 0.4.03.191                1
# 1.6.AGIR.SOZ              1
# 1.3.2-7                   1
# 01.01.2019                1
# 7.6.0-19032601            1
# 3.3.3001                  1
# 1.0.15.44                 1
# 4.40.55469                1
# 1.1.1-play                1
# 11.8.0                    1
# 2.3.3.1076                1
# 2.0.1.18                  1
# 25.07.8                   1
# 2.83.982                  1
# 1.8.0.01                  1
# Name: latest_version, Length: 22986, dtype: int64

# %%
data2[data2['latest_version']=='1.0.0']
# Out:
#                                                  app_name  \
# 102                        Archer Fighter: Stickman Fight
# 244                            Tiffany Alvord Dream World
# 566                                     Oddbods Turbo Run
# 1151              Fantasy Mosaics 33: Inventor's Workshop
# 1455                                    Sweet Face Camera
# 1755    Blood Pressure Checker Diary : BP Info :BP Tra...
# 1858                                    Occidental Heroes
# 2209                           My Little Pony Celebration
# 2923                        GuessUp Kids - Party Charades
# 3338                       Test Application - Daily Sub02
# 4310                                  Resep Bubur Spesial
# 4395                         New Toca Hair Salon 3 Images
# 4490                           Puppy Pug House Decoration
# 4668                              HelloSleepï¿½ by ResMed
# 4770                                  Presentation Remote
# 5530                                       ????? ????? FM
# 5533                                     ABC Memory Match
# 5538                                    Lush Meetings App
# 5541                                                 GPRM
# 5543                                        My ATA Events
# 5546                                    KuppingerCole App
# 5549                                           CTF Events
# 5550                                         Serco Events
# 5551                                                ISSSA
# 5692                                        CoCar Dashcam
# 5711                                     ???? ?? - ??????
# 5913                            Tamagotchi Classic - Gen1
# 6031                                           Sprint ARx
# 6637                                          G4A: Hearts
# 6888                          Tablecloth Crochet Patterns
# ...                                                   ...
# 266062                                 Psychometric Tests
# 266191               Stickers Collection Pack:WA Stickers
# 266192                     ??? ??????? - Vachan Sanjivani
# 266210                                      iMod Fracarro
# 266269                                    Belgium Podcast
# 266305                     Desapegaweb - Comprar e Vender
# 266373                                   Six Invitational
# 266394  KBBI Lengkap Kamus Besar Bahasa Indonesia Lengkap
# 266552                                               KRSM
# 266558                                     Surname Map UK
# 266582                                                ASP
# 266642    Alexandrian Witchcraft (Book of Shadows - Free)
# 266675                          Sky Wallpaper-Looking Up-
# 266708                                          Foodistry
# 266729                            Griezmann Wallpapers HD
# 266730                         House Design Wallpapers HD
# 266739                                     Tulcea CityApp
# 266741                                 Sighisoara CityApp
# 266743                              Visit Bistrita-Nasaud
# 266744                               Viseu de Sus CityApp
# 266745                                               EVPL
# 266854                                    Retro Parachute
# 266958                                             ??????
# 266985                       Al-Qur'an in Fulani Language
# 266989  CricLive - Cricket Live Scores, News & Comment...
# 266991                                     Poland Podcast
# 267000                     Tutorial learn to dance ballet
# 267002                   BTS, Kpop Music & Lyrics Offline
# 267013                            ???? ????? - ???? ?????
# 267020                          ????? ?????? ?????? ?????
#
#                    category    rating  reviews   installs        size  price  \
# 102             GAME_ACTION  4.301370    438.0   100000.0  38000000.0      0
# 244              GAME_MUSIC  4.369269  59672.0  1000000.0  46000000.0      0
# 566             GAME_ARCADE  4.528426   6086.0  1000000.0  89000000.0      0
# 1151            GAME_PUZZLE  5.000000      1.0      100.0  98000000.0      1
# 1455                 BEAUTY  3.704568   3984.0  1000000.0  22000000.0      0
# 1755                MEDICAL  4.040000     75.0    10000.0         2.1      0
# 1858      GAME_ROLE_PLAYING  4.373347   8922.0   500000.0  19000000.0      0
# 2209        GAME_SIMULATION  4.329068  66737.0  5000000.0  17000000.0      0
# 2923              GAME_WORD  5.000000     15.0      100.0  29000000.0      1
# 3338                 EVENTS  3.666667      3.0      100.0     53000.0      0
# 4310         FOOD_AND_DRINK  5.000000      1.0      100.0         5.4      0
# 4395          ENTERTAINMENT  1.487805     41.0     1000.0         3.5      0
# 4490          ENTERTAINMENT  4.442307     52.0    10000.0  30000000.0      0
# 4668     HEALTH_AND_FITNESS  5.000000      1.0       10.0  35000000.0      0
# 4770                  TOOLS  4.161074    149.0    10000.0         3.2      0
# 5530        MUSIC_AND_AUDIO  4.500000      8.0     1000.0         2.6      0
# 5533            GAME_PUZZLE  4.000000     15.0     5000.0         7.5      1
# 5538               BUSINESS  5.000000      1.0      100.0  26000000.0      0
# 5541               BUSINESS  4.466667     15.0     1000.0         2.5      0
# 5543               BUSINESS  4.714286     14.0     1000.0  25000000.0      0
# 5546               BUSINESS  5.000000      4.0      100.0  26000000.0      0
# 5549               BUSINESS  5.000000      1.0      100.0  23000000.0      0
# 5550               BUSINESS  4.333333      3.0      500.0  23000000.0      0
# 5551               BUSINESS  5.000000      1.0      100.0  24000000.0      0
# 5692    MAPS_AND_NAVIGATION  3.750000      4.0     1000.0  37000000.0      0
# 5711          ENTERTAINMENT  4.478571    140.0    50000.0         6.9      0
# 5913            GAME_CASUAL  3.779703    808.0    50000.0  14000000.0      1
# 6031                  TOOLS  5.000000      1.0     1000.0         NaN      0
# 6637              GAME_CARD  4.454545     11.0     1000.0  10000000.0      0
# 6888         ART_AND_DESIGN  4.317461     63.0    10000.0  31000000.0      0
# ...                     ...       ...      ...        ...         ...    ...
# 266062            EDUCATION  5.000000      1.0       10.0  23000000.0      1
# 266191       ART_AND_DESIGN  4.500000      2.0      100.0  14000000.0      0
# 266192  BOOKS_AND_REFERENCE  4.818182     11.0      100.0         8.4      0
# 266210                TOOLS  4.200000      5.0     1000.0         2.7      0
# 266269      MUSIC_AND_AUDIO  4.000000      1.0      500.0         2.1      0
# 266305             SHOPPING  2.857143      7.0     1000.0  25000000.0      0
# 266373        ENTERTAINMENT  4.314815     54.0     1000.0  16000000.0      0
# 266394            EDUCATION  4.250000     16.0     1000.0  15000000.0      0
# 266552        ENTERTAINMENT  5.000000      4.0      100.0  14000000.0      0
# 266558                TOOLS  3.000000      2.0     1000.0         2.1      0
# 266582             BUSINESS  5.000000      1.0        1.0         6.4      0
# 266642  BOOKS_AND_REFERENCE  2.250000      8.0     1000.0  46000000.0      0
# 266675      PERSONALIZATION  4.370536    224.0    10000.0         1.2      0
# 266708          GAME_PUZZLE  4.857143      7.0      100.0  28000000.0      1
# 266729               SPORTS  4.000000      4.0      500.0         8.6      0
# 266730       HOUSE_AND_HOME  5.000000      1.0       10.0         9.2      0
# 266739     TRAVEL_AND_LOCAL  5.000000      1.0       10.0         4.0      0
# 266741     TRAVEL_AND_LOCAL  3.625000      8.0      500.0         4.2      0
# 266743     TRAVEL_AND_LOCAL  5.000000      8.0      100.0         4.4      0
# 266744     TRAVEL_AND_LOCAL  4.666667      6.0       50.0         3.9      0
# 266745            EDUCATION  5.000000      1.0      100.0         5.9      0
# 266854          GAME_CASUAL  4.714286     28.0     1000.0  16000000.0      0
# 266958            EDUCATION  3.600000     15.0     1000.0    392000.0      0
# 266985            EDUCATION  4.840000     25.0     1000.0         9.9      0
# 266989               SPORTS  3.000000      2.0     1000.0         4.0      0
# 266991      MUSIC_AND_AUDIO  3.750000     12.0     1000.0         2.1      0
# 267000        ENTERTAINMENT  3.666667      3.0      100.0  10000000.0      0
# 267002      MUSIC_AND_AUDIO  4.018518    108.0     5000.0         8.9      0
# 267013  BOOKS_AND_REFERENCE  5.000000      3.0     1000.0  35000000.0      0
# 267020  BOOKS_AND_REFERENCE  4.833333     12.0     1000.0  19000000.0      0
#
#        content_rating last_updated minimum_version latest_version unnamed1  \
# 102              Teen   2019-02-20      4.1 and up          1.0.0      NaN
# 244          Everyone   2015-01-21      2.3 and up          1.0.0      NaN
# 566          Everyone   2019-01-31      4.1 and up          1.0.0      NaN
# 1151         Everyone   2019-02-24      4.0 and up          1.0.0      NaN
# 1455         Everyone   2018-11-13      4.0 and up          1.0.0      NaN
# 1755         Everyone   2019-02-18    4.0.3 and up          1.0.0      NaN
# 1858     Everyone 10+   2019-02-15      4.0 and up          1.0.0      NaN
# 2209         Everyone   2016-07-22      2.3 and up          1.0.0      NaN
# 2923         Everyone   2019-02-15      4.3 and up          1.0.0      NaN
# 3338         Everyone   2016-02-09      4.0 and up          1.0.0      NaN
# 4310         Everyone   2018-01-28      4.1 and up          1.0.0      NaN
# 4395         Everyone   2019-03-07      4.1 and up          1.0.0      NaN
# 4490         Everyone   2019-03-07      2.3 and up          1.0.0      NaN
# 4668         Everyone   2019-02-25      4.4 and up          1.0.0      NaN
# 4770         Everyone   2017-11-30      5.0 and up          1.0.0      NaN
# 5530         Everyone   2018-12-16      4.1 and up          1.0.0      NaN
# 5533         Everyone   2018-04-01      4.1 and up          1.0.0      NaN
# 5538         Everyone   2018-01-04      4.4 and up          1.0.0      NaN
# 5541         Everyone   2017-08-31      4.0 and up          1.0.0      NaN
# 5543         Everyone   2017-04-03      4.0 and up          1.0.0      NaN
# 5546         Everyone   2017-10-26      4.4 and up          1.0.0      NaN
# 5549         Everyone   2016-08-31      4.0 and up          1.0.0      NaN
# 5550         Everyone   2017-02-06      4.0 and up          1.0.0      NaN
# 5551         Everyone   2017-08-08      4.0 and up          1.0.0      NaN
# 5692         Everyone   2017-03-10      5.0 and up          1.0.0      NaN
# 5711         Everyone   2018-01-26      4.0 and up          1.0.0      NaN
# 5913         Everyone   2015-04-23      2.3 and up          1.0.0      NaN
# 6031         Everyone   2018-11-15      4.4 and up          1.0.0      NaN
# 6637         Everyone   2018-11-30      4.1 and up          1.0.0      NaN
# 6888         Everyone   2018-10-13    4.0.3 and up          1.0.0      NaN
# ...               ...          ...             ...            ...      ...
# 266062       Everyone   2019-01-18      4.4 and up          1.0.0      NaN
# 266191       Everyone   2018-11-21    4.0.3 and up          1.0.0      NaN
# 266192       Everyone   2019-01-04    4.0.3 and up          1.0.0      NaN
# 266210       Everyone   2017-10-12      5.0 and up          1.0.0      NaN
# 266269       Everyone   2018-05-14      4.1 and up          1.0.0      NaN
# 266305       Everyone   2018-01-10      4.1 and up          1.0.0      NaN
# 266373       Everyone   2019-02-07      4.4 and up          1.0.0      NaN
# 266394       Everyone   2018-10-07    4.0.3 and up          1.0.0      NaN
# 266552       Everyone   2017-08-22      4.0 and up          1.0.0      NaN
# 266558       Everyone   2018-08-18    4.0.3 and up          1.0.0      NaN
# 266582       Everyone   2019-02-03      4.1 and up          1.0.0      NaN
# 266642       Everyone   2017-08-20      4.1 and up          1.0.0      NaN
# 266675       Everyone   2015-03-18      2.1 and up          1.0.0      NaN
# 266708       Everyone   2015-04-19    2.3.3 and up          1.0.0      NaN
# 266729       Everyone   2019-01-05      4.0 and up          1.0.0      NaN
# 266730       Everyone   2018-12-31      4.0 and up          1.0.0      NaN
# 266739       Everyone   2019-02-05      4.4 and up          1.0.0      NaN
# 266741       Everyone   2017-09-01      4.4 and up          1.0.0      NaN
# 266743       Everyone   2017-10-16      4.4 and up          1.0.0      NaN
# 266744       Everyone   2018-04-23      4.4 and up          1.0.0      NaN
# 266745       Everyone   2018-12-28      4.4 and up          1.0.0      NaN
# 266854       Everyone   2018-05-13      5.0 and up          1.0.0      NaN
# 266958       Everyone   2015-01-19      2.2 and up          1.0.0      NaN
# 266985       Everyone   2018-07-06      4.0 and up          1.0.0      NaN
# 266989       Everyone   2018-02-27    4.0.3 and up          1.0.0      NaN
# 266991       Everyone   2018-05-16      4.1 and up          1.0.0      NaN
# 267000       Everyone   2019-01-17      4.4 and up          1.0.0      NaN
# 267002       Everyone   2018-12-11      4.2 and up          1.0.0      NaN
# 267013       Everyone   2019-01-21      4.1 and up          1.0.0      NaN
# 267020       Everyone   2019-01-25      3.0 and up          1.0.0      NaN
#
#        unnamed2 unnamed3  unnamed4
# 102         NaN      NaN       NaN
# 244         NaN      NaN       NaN
# 566         NaN      NaN       NaN
# 1151        NaN      NaN       NaN
# 1455        NaN      NaN       NaN
# 1755        NaN      NaN       NaN
# 1858        NaN      NaN       NaN
# 2209        NaN      NaN       NaN
# 2923        NaN      NaN       NaN
# 3338        NaN      NaN       NaN
# 4310        NaN      NaN       NaN
# 4395        NaN      NaN       NaN
# 4490        NaN      NaN       NaN
# 4668        NaN      NaN       NaN
# 4770        NaN      NaN       NaN
# 5530        NaN      NaN       NaN
# 5533        NaN      NaN       NaN
# 5538        NaN      NaN       NaN
# 5541        NaN      NaN       NaN
# 5543        NaN      NaN       NaN
# 5546        NaN      NaN       NaN
# 5549        NaN      NaN       NaN
# 5550        NaN      NaN       NaN
# 5551        NaN      NaN       NaN
# 5692        NaN      NaN       NaN
# 5711        NaN      NaN       NaN
# 5913        NaN      NaN       NaN
# 6031        NaN      NaN       NaN
# 6637        NaN      NaN       NaN
# 6888        NaN      NaN       NaN
# ...         ...      ...       ...
# 266062      NaN      NaN       NaN
# 266191      NaN      NaN       NaN
# 266192      NaN      NaN       NaN
# 266210      NaN      NaN       NaN
# 266269      NaN      NaN       NaN
# 266305      NaN      NaN       NaN
# 266373      NaN      NaN       NaN
# 266394      NaN      NaN       NaN
# 266552      NaN      NaN       NaN
# 266558      NaN      NaN       NaN
# 266582      NaN      NaN       NaN
# 266642      NaN      NaN       NaN
# 266675      NaN      NaN       NaN
# 266708      NaN      NaN       NaN
# 266729      NaN      NaN       NaN
# 266730      NaN      NaN       NaN
# 266739      NaN      NaN       NaN
# 266741      NaN      NaN       NaN
# 266743      NaN      NaN       NaN
# 266744      NaN      NaN       NaN
# 266745      NaN      NaN       NaN
# 266854      NaN      NaN       NaN
# 266958      NaN      NaN       NaN
# 266985      NaN      NaN       NaN
# 266989      NaN      NaN       NaN
# 266991      NaN      NaN       NaN
# 267000      NaN      NaN       NaN
# 267002      NaN      NaN       NaN
# 267013      NaN      NaN       NaN
# 267020      NaN      NaN       NaN
#
# [4146 rows x 15 columns]

# %%
data2.groupby('minimum_version')['minimum_version'].count().sort_values(ascending=False)
# Out:
# minimum_version
# 4.1 and up            70848
# 4.0.3 and up          49324
# 4.0 and up            37837
# 4.4 and up            28250
# 5.0 and up            17413
# 4.2 and up            13629
# 2.3 and up            11895
# Varies with device     8029
# 4.3 and up             5267
# 2.2 and up             4873
# 2.3.3 and up           4797
# 3.0 and up             4312
# 2.1 and up             2378
# 6.0 and up             2143
# 1.6 and up             1650
# 5.1 and up             1001
# 3.2 and up              616
# 7.0 and up              550
# 4.4W and up             456
# 2.0 and up              423
# 1.5 and up              409
# 3.1 and up              350
# 8.0 and up              223
# 1.0 and up               95
# 2.0.1 and up             91
# 7.1 and up               46
# 1.1 and up               15
# 4.1 - 7.1.1              12
# 4.1 - 8.0                11
# 4.0.3 - 8.0               5
#                       ...
# 1.6 - 4.0.4               1
# 2.3 - 4.4W                1
# 1.5 - 4.0.2               1
# 2.3 - 7.1.1               1
# 4.0 - 5.0                 1
# 2.3.3 - 4.4               1
# 4.0.3 - 7.1.1             1
# 5.0 - 7.1.1               1
# 4.4W - 8.0                1
# 4.3 - 4.4                 1
# 4.2 - 8.0                 1
# 4.2 - 7.1.1               1
# 4.2 - 4.4W                1
# 4.2 - 4.3                 1
# 4.2 - 4.2.2               1
# 4.1 - 7.0                 1
# 4.1 - 4.4                 1
# 4.0.3 - 4.4W              1
# 2.3.3 - 4.4W              1
# 4.0.3 - 4.4               1
# 4.0 - 7.0                 1
# 4.0 - 6.0                 1
# 4.0 - 5.1                 1
# 4.0 - 4.4W                1
# 4.0 - 4.2.2               1
# 3.1 - 8.0                 1
# 3.0 - 7.1.1               1
# 2.3.3 - 7.1.1             1
# 2.3.3 - 5.1               1
# 1.0 - 6.0                 1
# Name: minimum_version, Length: 83, dtype: int64

# %%
data2.groupby('category')['category'].count().sort_values(ascending=False)
# Out:
# category
# EDUCATION              33394
# TOOLS                  21592
# BOOKS_AND_REFERENCE    21377
# ENTERTAINMENT          20604
# MUSIC_AND_AUDIO        17876
# LIFESTYLE              15034
# PERSONALIZATION        10544
# FINANCE                10342
# BUSINESS               10230
# PRODUCTIVITY            9142
# NEWS_AND_MAGAZINES      8030
# HEALTH_AND_FITNESS      7537
# PHOTOGRAPHY             7240
# TRAVEL_AND_LOCAL        6649
# SPORTS                  5585
# COMMUNICATION           5486
# SHOPPING                5337
# SOCIAL                  4744
# MAPS_AND_NAVIGATION     4094
# MEDICAL                 3736
# GAME_PUZZLE             3620
# FOOD_AND_DRINK          3170
# VIDEO_PLAYERS           2717
# GAME_CASUAL             2426
# GAME_ARCADE             2343
# AUTO_AND_VEHICLES       2104
# GAME_EDUCATIONAL        2007
# ART_AND_DESIGN          1758
# WEATHER                 1643
# GAME_SIMULATION         1607
# GAME_ACTION             1482
# GAME_CARD               1183
# GAME_ADVENTURE          1055
# GAME_ROLE_PLAYING       1035
# GAME_BOARD               968
# BEAUTY                   959
# GAME_WORD                946
# HOUSE_AND_HOME           925
# GAME_STRATEGY            913
# GAME_RACING              778
# GAME_SPORTS              772
# GAME_TRIVIA              753
# PARENTING                621
# EVENTS                   615
# LIBRARIES_AND_DEMO       612
# COMICS                   505
# GAME_CASINO              367
# DATING                   323
# GAME_MUSIC               253
# TRAVEL                     1
# Name: category, dtype: int64

# %%
data3=data2[data2['latest_version']=='1.0.0']

# %%
list=data3.groupby('category')['category'].count().sort_values(ascending=False).head(10).index.tolist()

# %%
data4=data3[data3['category'].isin(list)]

# %%
dummies=pd.get_dummies(data4.category)

# %%
dummies.head()
# Out:
#       BOOKS_AND_REFERENCE  BUSINESS  EDUCATION  ENTERTAINMENT  FINANCE  \
# 4395                    0         0          0              1        0
# 4490                    0         0          0              1        0
# 4770                    0         0          0              0        0
# 5530                    0         0          0              0        0
# 5538                    0         1          0              0        0
#
#       LIFESTYLE  MUSIC_AND_AUDIO  PERSONALIZATION  PRODUCTIVITY  TOOLS
# 4395          0                0                0             0      0
# 4490          0                0                0             0      0
# 4770          0                0                0             0      1
# 5530          0                1                0             0      0
# 5538          0                0                0             0      0

# %%
merged=pd.concat([data4,dummies],axis='columns')

# %%
merged
# Out:
#                                                  app_name  \
# 4395                         New Toca Hair Salon 3 Images
# 4490                           Puppy Pug House Decoration
# 4770                                  Presentation Remote
# 5530                                       ????? ????? FM
# 5538                                    Lush Meetings App
# 5541                                                 GPRM
# 5543                                        My ATA Events
# 5546                                    KuppingerCole App
# 5549                                           CTF Events
# 5550                                         Serco Events
# 5551                                                ISSSA
# 5711                                     ???? ?? - ??????
# 6031                                           Sprint ARx
# 6889                              Learn to crochet easily
# 6973                     Cooking Foods in Outdoor Kitchen
# 6976               Watermelon Ice Cream and Candy Cooking
# 7058                              One Piece - Watch Free!
# 7510                       Caustic Editor for VolcaSample
# 7583                    Sinï¿½nimos y Antï¿½nimos Offline
# 7713                                   Karting Vuiteboeuf
# 7714                                           Stras Kart
# 7715                                      Karting Payerne
# 7716                                     Metz Kart Indoor
# 7821                             FurReal Maker: Proto Max
# 8702                                            mobi kino
# 9505              XPERIAï¿½ The Four Elements - Air Theme
# 9506             XPERIAï¿½ The Four Elements - Fire Theme
# 9895                    Workline - Possibilities Infinite
# 9919                                  ??????? ???? ? ????
# 9934                       Hardevbani - Nirankari Mission
# ...                                                   ...
# 265408                                    Psychology Book
# 265459                                  What Is Salvation
# 265493                                Belajar Shalat Anak
# 265794          Podatnik.info - rozlicz PIT przez telefon
# 265795                                   Chinese Keyboard
# 265823                        Round Compass - Simple Nav.
# 265962                   Kode Game PS3 Terlengkap Offline
# 265995                                        Noor Taibah
# 265997                                           AnaAtlou
# 266015                               ????? ???? ????? ???
# 266045                Theme for Samsung Galaxy S7 Edge HD
# 266062                                 Psychometric Tests
# 266192                     ??? ??????? - Vachan Sanjivani
# 266210                                      iMod Fracarro
# 266269                                    Belgium Podcast
# 266373                                   Six Invitational
# 266394  KBBI Lengkap Kamus Besar Bahasa Indonesia Lengkap
# 266552                                               KRSM
# 266558                                     Surname Map UK
# 266582                                                ASP
# 266642    Alexandrian Witchcraft (Book of Shadows - Free)
# 266675                          Sky Wallpaper-Looking Up-
# 266745                                               EVPL
# 266958                                             ??????
# 266985                       Al-Qur'an in Fulani Language
# 266991                                     Poland Podcast
# 267000                     Tutorial learn to dance ballet
# 267002                   BTS, Kpop Music & Lyrics Offline
# 267013                            ???? ????? - ???? ?????
# 267020                          ????? ?????? ?????? ?????
#
#                    category    rating  reviews  installs        size  price  \
# 4395          ENTERTAINMENT  1.487805     41.0    1000.0         3.5      0
# 4490          ENTERTAINMENT  4.442307     52.0   10000.0  30000000.0      0
# 4770                  TOOLS  4.161074    149.0   10000.0         3.2      0
# 5530        MUSIC_AND_AUDIO  4.500000      8.0    1000.0         2.6      0
# 5538               BUSINESS  5.000000      1.0     100.0  26000000.0      0
# 5541               BUSINESS  4.466667     15.0    1000.0         2.5      0
# 5543               BUSINESS  4.714286     14.0    1000.0  25000000.0      0
# 5546               BUSINESS  5.000000      4.0     100.0  26000000.0      0


# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.svm import SVC

# %%
plt.figure(figsize=(16,20))
sns.countplot(y='category',data=data2)
plt.show()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267034 entries, 0 to 267051
# Data columns (total 15 columns):
# app_name           267033 non-null object
# category           267034 non-null object
# rating             267034 non-null float64
# reviews            267034 non-null float64
# installs           267034 non-null float64
# size               255308 non-null float64
# price              267034 non-null int64
# content_rating     267034 non-null object
# last_updated       267034 non-null object
# minimum_version    267033 non-null object
# latest_version     267031 non-null object
# unnamed1           0 non-null object
# unnamed2           0 non-null object
# unnamed3           0 non-null object
# unnamed4           0 non-null float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 42.6+ MB

# %%
dt_ctg=data2.groupby('category',as_index=False)['rating'].mean()
dt_ctg.head()
# Out:
#               category    rating
# 0       ART_AND_DESIGN  4.229019
# 1    AUTO_AND_VEHICLES  4.126978
# 2               BEAUTY  4.296484
# 3  BOOKS_AND_REFERENCE  4.475828
# 4             BUSINESS  4.142819

# %%
dt_rvws=data2.groupby('reviews',as_index=False)['rating'].mean()
dt_rvws.head(10)
# Out:
#    reviews    rating
# 0      1.0  4.411388
# 1      2.0  4.343754
# 2      3.0  4.280993
# 3      4.0  4.310032
# 4      5.0  4.283669
# 5      6.0  4.284290
# 6      7.0  4.282838
# 7      8.0  4.270578
# 8      9.0  4.276315
# 9     10.0  4.265822

# %%
dt_sz=data2.groupby('size',as_index=False)['rating'].mean()
dt_sz.head(10)
# Out:
#    size    rating
# 0   1.0  4.235779
# 1   1.1  4.181199
# 2   1.2  4.199767
# 3   1.3  4.180118
# 4   1.4  4.216732
# 5   1.5  4.220023
# 6   1.6  4.244187
# 7   1.7  4.241015
# 8   1.8  4.206780
# 9   1.9  4.257990

# %%
dt_in=data2.groupby('installs',as_index=False)['rating'].mean()
dt_in.head(6)
# Out:
#    installs    rating
# 0       0.0  4.334034
# 1       1.0  4.824496
# 2       5.0  4.812350
# 3      10.0  4.649256
# 4      50.0  4.537872
# 5     100.0  4.401526

# %%
dt_prc=data2.groupby('price',as_index=False)['rating'].mean()
dt_prc.head(10)
# Out:
#    price    rating
# 0      0  4.267476
# 1      1  4.311198

# %%
dt_cr=data2.groupby('content_rating',as_index=False)['rating'].mean()
dt_cr.head(10)
# Out:
#     content_rating    rating
# 0  Adults only 18+  4.141135
# 1         Everyone  4.264807
# 2     Everyone 10+  4.291600
# 3       Mature 17+  4.241863
# 4             Teen  4.333072
# 5          Unrated  4.221259

# %%
dt_av=data2.groupby('minimum_version',as_index=False)['rating'].mean()
dt_av.head()
# Out:
#   minimum_version    rating
# 0       1.0 - 6.0  4.111111
# 1      1.0 and up  4.262285
# 2      1.1 and up  4.183094
# 3     1.5 - 4.0.2  4.426829
# 4      1.5 and up  4.117667

# %%
sns.countplot(x='price',data=data2)

# %%
sns.barplot(x='price', y='rating', data=data2)

# %%
plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(x='content_rating', y='rating', hue="price", data=data2, estimator=np.median)
plt.show()

# %%
plt.figure(num=None, figsize=(12, 6), dpi=80, facecolor='w', edgecolor='k')
sns.boxplot(x='content_rating', y='rating', hue="price", data=data2)
plt.show()

# %%
plt.figure(figsize=(16,18))
sns.countplot(y='category',data=data2)
plt.show()

# %%
plt.figure(num=None, figsize=(8, 15), dpi=80, facecolor='w', edgecolor='k')

# specify hue="categorical_variable"
sns.barplot(y='category', x='rating', hue="price", data=data2, estimator=np.median)
plt.show()

# %%
sns.countplot(x='content_rating',data=data2)

# %%
sns.boxplot(x='content_rating', y='rating', data=data2)

# %%
sns.barplot(x='content_rating', y='rating', data=data2)

# %%
plt.figure(figsize=(10, 25))
sns.barplot(y='minimum_version', x='rating', data=data2)
plt.show()

# %%
data2.hist(figsize=(8,8))
plt.figure()

# %%
data2.isnull().sum().sum()
# Out:
# 1079867

# %%
total=data2.isnull().sum()
percent = (data2.isnull().sum()/data2.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(13)
# Out:
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#                   Total   Percent
# app_name              1  0.000004
# category              0  0.000000
# content_rating        0  0.000000
# installs              0  0.000000
# last_updated          0  0.000000
# latest_version        3  0.000011
# minimum_version       1  0.000004
# price                 0  0.000000
# rating                0  0.000000
# reviews               0  0.000000
# size              11726  0.043912
# unnamed1         267034  1.000000
# unnamed2         267034  1.000000

# %%
data2.dropna(axis=1,how='all',inplace=True)

# %%
data2.dropna(inplace=True)

# %%
data2
# Out:
#                                                  app_name  \
# 2                                                  Peapod
# 3                         foodpanda - Local Food Delivery
# 5                                 Safeway Online Shopping
# 8          Fast Food Locator | Worldwide Fast Food Finder
# 12                                            FreshDirect
# 13                      Easy Healthy Recipes for free app
# 16                                            Chick-fil-A
# 18       Seamless: Restaurant Takeout & Food Delivery App
# 19                                           Food Planner
# 20                      Cookpad - Create your own Recipes
# 22                                 Schwan's Food Delivery
# 23                    Google Express - Shopping done fast
# 24                                       Amazon Prime Now
# 25                               BeyondMenu Food Delivery
# 26                                                Walmart
# 27                    DELISH KITCHEN - ??????????????????
# 28      Grubhub: Local Food Delivery & Restaurant Takeout
# 29                         OpenTable: Restaurants Near Me
# 30                                             McDonald's
# 31                                          Recipe Keeper
# 32                                   Vons Online Shopping
# 33                              ?????? - McDonald's Japan
# 34                          ?????? - ????????????????????
# 36                                             McDonald's
# 37                         Yummly Recipes & Shopping List
# 39                            Instacart: Grocery Delivery
# 40          Postmates Food Delivery: Order Eats & Alcohol
# 41                                                  Tasty
# 42                         ChefTap Recipes & Grocery List
# 43      BigOven Recipes, Meal Planner, Grocery List & ...
# ...                                                   ...
# 267022                 ???? ??? ??????? ?????? ???? ?????
# 267023                                          everisyou
# 267024                                    Bricks Breakout
# 267025                                     Perfect Violin
# 267026            Jany Pehcahny Se Ajnabi by Sawera Ahmad
# 267027   Triceps Workout - 30 Effective Triceps Exercises
# 267028                         ?? - ??? ?? ?? ??? ???? ??
# 267029                Bus365 - Bus Reservation System App
# 267030                                     ProgTV Android
# 267031                                      Quantum VJ HD
# 267032                              SIMULIZI ZA KUSISIMUA
# 267033                  Bangla Alphabets (????? ????????)
# 267034                               Blood Pressure Diary
# 267035                                        Betpera.com
# 267036                            ???????????? ?? ???????
# 267037       German Learning App From Bangla For Free Use
# 267038                      Interamerica cree en profetas
# 267039                       Stuffed Baked Potato Factory
# 267040                           Voice Search Recognation
# 267041                        PMHNP Practice Test 2018 Ed
# 267042                       XHPZ 96.7 FM RADIO SENSACION
# 267043                                           Kicker U
# 267044                      Masteran Cucak Ijo Terlengkap
# 267045    Boys Men Hairstyles and Boys Hair cuts NEW 2019
# 267046     ??????????????????????: ???????????? ?????????
# 267047                               Community Healthplex
# 267048                                Pet ads: Buy & Sell
# 267049                      Collectors Market: Buy & Sell
# 267050                             Car Market, Buy & Sell
# 267051                          Selfie with Ariana Grande
#
#                    category    rating   reviews    installs        size  \
# 2                  SHOPPING  3.656329    1967.0    100000.0         1.4
# 3            FOOD_AND_DRINK  4.107233  389154.0  10000000.0  16000000.0
# 5            FOOD_AND_DRINK  3.825322    2559.0    100000.0  23000000.0
# 8          TRAVEL_AND_LOCAL  3.811765      85.0     10000.0         4.1
# 12                LIFESTYLE  3.213528     754.0    100000.0  39000000.0
# 13           FOOD_AND_DRINK  4.160279     287.0    100000.0         8.1
# 16           FOOD_AND_DRINK  4.374691   52526.0   5000000.0  19000000.0
# 18           FOOD_AND_DRINK  4.517922   41597.0   1000000.0  30000000.0
# 19           FOOD_AND_DRINK  3.909142   10764.0   1000000.0  11000000.0
# 20           FOOD_AND_DRINK  4.514294  164089.0  10000000.0  11000000.0
# 22                 SHOPPING  4.248818    4867.0    500000.0  23000000.0
# 23                 SHOPPING  3.813572    8223.0   1000000.0  14000000.0
# 24                 SHOPPING  3.924423   24849.0  10000000.0  38000000.0
# 25           FOOD_AND_DRINK  4.689527   62730.0   1000000.0  15000000.0
# 26                 SHOPPING  4.420088  467761.0  10000000.0  55000000.0
# 27           FOOD_AND_DRINK  4.568305   39280.0   1000000.0         7.8
# 28           FOOD_AND_DRINK  4.397298  217693.0  10000000.0  30000000.0
# 29           FOOD_AND_DRINK  4.599673  103468.0   5000000.0  17000000.0
# 30           FOOD_AND_DRINK  3.626533  262042.0  10000000.0  62000000.0
# 31           FOOD_AND_DRINK  4.494902    2746.0    100000.0  22000000.0
# 32           FOOD_AND_DRINK  3.990586     956.0    100000.0  25000000.0
# 33           FOOD_AND_DRINK  3.439350  131608.0  10000000.0  46000000.0
# 34           FOOD_AND_DRINK  4.177659   71930.0  10000000.0  17000000.0
# 36           FOOD_AND_DRINK  3.590384   63540.0  10000000.0  30000000.0
# 37           FOOD_AND_DRINK  4.548566   98464.0   5000000.0  22000000.0
# 39           FOOD_AND_DRINK  4.334735   24733.0   1000000.0  14000000.0
# 40           FOOD_AND_DRINK  3.775403   47957.0   5000000.0  22000000.0
# 41           FOOD_AND_DRINK  4.729073   26963.0   1000000.0         9.5
# 42           FOOD_AND_DRINK  4.486800    9318.0    500000.0  15000000.0
# 43           FOOD_AND_DRINK  4.318519   32356.0   1000000.0  78000000.0
# ...                     ...       ...       ...         ...         ...
# 267022  BOOKS_AND_REFERENCE  3.973039     816.0    100000.0  29000000.0
# 267023         PRODUCTIVITY  4.172043      93.0      5000.0  17000000.0
# 267024          GAME_ARCADE  4.400000       5.0       100.0         2.4
# 267025      MUSIC_AND_AUDIO  1.800000      10.0      1000.0         4.7
# 267026  BOOKS_AND_REFERENCE  5.000000       5.0       100.0  43000000.0
# 267027   HEALTH_AND_FITNESS  5.000000       2.0      1000.0         6.3
# 267028    GAME_ROLE_PLAYING  4.063430    1277.0    500000.0  98000000.0
# 267029     TRAVEL_AND_LOCAL  5.000000       1.0        50.0  15000000.0
# 267030        VIDEO_PLAYERS  3.968778    8968.0   1000000.0  35000000.0
# 267031       ART_AND_DESIGN  4.500000      22.0       100.0         2.2
# 267032        ENTERTAINMENT  4.600386     518.0      5000.0         5.3
# 267033            EDUCATION  3.545455      11.0      1000.0  21000000.0
# 267034              MEDICAL  4.000000       1.0       100.0         4.6
# 267035               SPORTS  4.500000      36.0      5000.0         3.5
# 267036    AUTO_AND_VEHICLES  3.767442      43.0       500.0         7.1
# 267037            EDUCATION  4.512195      82.0     10000.0  24000000.0
# 267038  BOOKS_AND_REFERENCE  3.287879      66.0      5000.0         2.1
# 267039             SHOPPING  4.638298      47.0      5000.0  13000000.0
# 267040        COMMUNICATION  4.045455      22.0      5000.0         3.9
# 267041            EDUCATION  4.500000       4.0       500.0         5.5
# 267042      MUSIC_AND_AUDIO  4.500000      14.0       500.0         3.2
# 267043            LIFESTYLE  4.068702     131.0      5000.0  37000000.0
# 267044        ENTERTAINMENT  4.176471      34.0      1000.0  26000000.0
# 267045            LIFESTYLE  5.000000       3.0       100.0  12000000.0
# 267046               COMICS  4.400000       5.0       100.0         7.0
# 267047   HEALTH_AND_FITNESS  5.000000       1.0       100.0         4.2
# 267048             BUSINESS  2.600000       5.0       500.0         8.4
# 267049             BUSINESS  3.285714       7.0      1000.0         7.9
# 267050             BUSINESS  5.000000       1.0      1000.0         8.2
# 267051          PHOTOGRAPHY  4.611111      18.0      1000.0         7.8
#
#         price content_rating last_updated     minimum_version  \
# 2           0       Everyone   2018-09-20          5.0 and up
# 3           0       Everyone   2019-03-22          4.2 and up
# 5           0       Everyone   2019-03-29          5.0 and up
# 8           0       Everyone   2019-02-10          4.3 and up
# 12          0       Everyone   2019-03-27          5.0 and up
# 13          0       Everyone   2019-03-07          4.0 and up
# 16          0       Everyone   2019-03-21          5.0 and up
# 18          0       Everyone   2019-03-28          5.0 and up
# 19          0       Everyone   2019-04-01        4.0.3 and up
# 20          0       Everyone   2019-04-02          4.4 and up
# 22          0       Everyone   2018-11-29        4.0.3 and up
# 23          0       Everyone   2019-03-26          4.2 and up
# 24          0           Teen   2019-03-15          5.0 and up
# 25          0       Everyone   2019-04-02          5.0 and up
# 26          0       Everyone   2019-03-28  Varies with device
# 27          0       Everyone   2019-03-31          4.1 and up
# 28          0       Everyone   2019-03-28          5.0 and up
# 29          0       Everyone   2019-03-29          5.0 and up
# 30          0       Everyone   2019-04-02          4.4 and up
# 31          0       Everyone   2018-12-01          4.1 and up
# 32          0       Everyone   2019-03-29          5.0 and up
# 33          0       Everyone   2019-04-01        4.0.3 and up
# 34          0       Everyone   2019-04-03          5.0 and up
# 36          0       Everyone   2019-03-18          4.2 and up
# 37          0       Everyone   2019-04-02          4.4 and up
# 39          0       Everyone   2019-04-02          5.0 and up
# 40          0       Everyone   2019-03-29          5.0 and up
# 41          0       Everyone   2019-04-02          5.0 and up
# 42          0       Everyone   2019-02-15          5.1 and up
# 43          0           Teen   2019-03-06          5.0 and up
# ...       ...            ...          ...                 ...
# 267022      0       Everyone   2017-10-26          3.0 and up
# 267023      0       Everyone   2019-03-26          5.0 and up
# 267024      0       Everyone   2016-11-02          3.2 and up
# 267025      0       Everyone   2017-01-17        4.0.3 and up
# 267026      0       Everyone   2019-03-22        4.0.3 and up
# 267027      0       Everyone   2018-07-29        4.0.3 and up
# 267028      0           Teen   2019-02-18          4.1 and up
# 267029      0       Everyone   2019-03-28          4.1 and up
# 267030      0       Everyone   2019-04-02          4.1 and up
# 267031      1       Everyone   2016-12-22          2.3 and up
# 267032      0       Everyone   2019-01-05        4.0.3 and up
# 267033      0       Everyone   2018-10-05          4.1 and up
# 267034      0       Everyone   2018-11-21          4.0 and up
# 267035      0       Everyone   2018-05-03        4.0.3 and up
# 267036      0           Teen   2019-02-13          4.1 and up
# 267037      0       Everyone   2018-05-02        4.0.3 and up
# 267038      0       Everyone   2017-07-09        4.0.3 and up
# 267039      0       Everyone   2018-05-07          4.1 and up
# 267040      0       Everyone   2018-03-27          4.4 and up
# 267041      0       Everyone   2018-09-28          4.3 and up
# 267042      0       Everyone   2016-04-29        2.3.3 and up
# 267043      1       Everyone   2018-06-13        4.0.3 and up
# 267044      0       Everyone   2018-10-29          4.1 and up
# 267045      0       Everyone   2019-02-10          4.1 and up
# 267046      0       Everyone   2019-01-24        4.0.3 and up
# 267047      0       Everyone   2018-07-27          5.0 and up
# 267048      0       Everyone   2018-10-22        4.0.3 and up
# 267049      0       Everyone   2019-03-13        4.0.3 and up
# 267050      0       Everyone   2018-08-27        4.0.3 and up
# 267051      0       Everyone   2018-10-03        4.0.3 and up
#
#               latest_version
# 2                      2.2.0
# 3                     4.18.2
# 5                      7.6.0
# 8                        2.4
# 12                       6.7
# 13                    25.5.0
# 16                     6.1.0
# 18                       7.3
# 19            5.1.3.0-google
# 20         2.106.4.0-android
# 22                     2.1.2
# 23      v42 (March 15, 2019)
# 24                    4.17.0
# 25                      2.61
# 26                     19.11
# 27                     2.5.7
# 28                       7.3
# 29              10.13.1.2500
# 30                    5.23.0
# 31                  3.20.0.0
# 32                     7.6.0
# 33                    4.0.41
# 34                 19.14.0.7
# 36                    1.2.20
# 37                       3.4
# 39                    5.17.3
# 40                     5.1.5
# 41                    1.12.0
# 42                 4.0.0.429
# 43                     5.8.4
# ...                      ...
# 267022                 1.0.1
# 267023                 3.0.4
# 267024                   1.1
# 267025                     1
# 267026                     1
# 267027                     1
# 267028               4.96.02
# 267029                 1.4.8
# 267030                2.51.5
# 267031                     1
# 267032                   9.3
# 267033               1.0.0.3
# 267034                     1
# 267035                   8.2
# 267036                   1.1
# 267037                 2.0.3
# 267038                0.0.92
# 267039                 2.0.6
# 267040                   1.1
# 267041                 2.0.3
# 267042                37.1.3
# 267043                  3.04
# 267044                     2
# 267045                   1.1
# 267046                   1.1
# 267047             1.0.4.228
# 267048                   1.8
# 267049                   2.4
# 267050                   1.7
# 267051                     1
#
# [255304 rows x 11 columns]

# %%
catgry=pd.get_dummies(data2['category'],prefix='catg',drop_first=True)
typ=pd.get_dummies(data2['price'],prefix='typ',drop_first=True)
cr=pd.get_dummies(data2['content_rating'],prefix='cr',drop_first=True)
frames=[data2,catgry,typ,cr]
data=pd.concat(frames,axis=1)
data.drop(['category','installs','price','content_rating'],axis=1,inplace=True)

# %%
data.drop(['app_name','size','last_updated','minimum_version','latest_version'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#       rating   reviews  catg_AUTO_AND_VEHICLES  catg_BEAUTY  \
# 2   3.656329    1967.0                       0            0
# 3   4.107233  389154.0                       0            0
# 5   3.825322    2559.0                       0            0
# 8   3.811765      85.0                       0            0
# 12  3.213528     754.0                       0            0
#
#     catg_BOOKS_AND_REFERENCE  catg_BUSINESS  catg_COMICS  catg_COMMUNICATION  \
# 2                          0              0            0                   0
# 3                          0              0            0                   0
# 5                          0              0            0                   0
# 8                          0              0            0                   0
# 12                         0              0            0                   0
#
#     catg_DATING  catg_EDUCATION  ...  catg_TRAVEL  catg_TRAVEL_AND_LOCAL  \
# 2             0               0  ...            0                      0
# 3             0               0  ...            0                      0
# 5             0               0  ...            0                      0
# 8             0               0  ...            0                      1
# 12            0               0  ...            0                      0
#
#     catg_VIDEO_PLAYERS  catg_WEATHER  typ_1  cr_Everyone  cr_Everyone 10+  \
# 2                    0             0      0            1                0
# 3                    0             0      0            1                0
# 5                    0             0      0            1                0
# 8                    0             0      0            1                0
# 12                   0             0      0            1                0
#
#     cr_Mature 17+  cr_Teen  cr_Unrated
# 2               0        0           0
# 3               0        0           0
# 5               0        0           0
# 8               0        0           0
# 12              0        0           0
#
# [5 rows x 57 columns]

# %%
X=data.drop('rating',axis=1)
y=data['rating'].values
y=y.astype('int')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)
# Out:
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
X_train
# Out:
# array([[ 1.0726935 , -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342],
#        [-0.04222158, -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342],
#        [-0.04299064, -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342],
#        ...,
#        [-0.04312107, -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342],
#        [-0.04071943, -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342],
#        [-0.04320652, -0.08891348, -0.06139614, ..., -0.11498125,
#         -0.26169594, -0.01128342]])

# %%
lr_c=LogisticRegression(random_state=4)
lr_c.fit(X_train,y_train)
lr_pred=lr_c.predict(X_test)
lr_ac=accuracy_score(y_test, lr_pred)
print('Logistic_Regression_accuracy:',lr_ac)
# Out:
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\SAMRAT ROY\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Logistic_Regression_accuracy: 0.6843579248350012
